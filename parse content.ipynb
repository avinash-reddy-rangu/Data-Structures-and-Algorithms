# %%
import requests 
from bs4 import BeautifulSoup 
import csv 
   
URL = "https://elearning.ravindrababuravula.com/course/dashboard/25"
r = requests.get(URL) 
   
soup = BeautifulSoup(r.content, 'html.parser') 
   
quotes=[]  # a list to store quotes 
   
table = soup.find('div', attrs = {"class":"tab-content course-tab-content"})

# %%
table

# %%
table

# %%
json1 = {
  "success": True,
  "lectures": [
    {
      "id": "4686",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Introduction to tree traversals",
      "duration_hm": "14:11",
      "num_of_question": "0"
    },
    {
      "id": "4644",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Direct Address Table",
      "duration_hm": "8:35",
      "num_of_question": "0"
    },
    {
      "id": "4620",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Introduction to stacks",
      "duration_hm": "6:28",
      "num_of_question": "0"
    },
    {
      "id": "4645",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Introduction to Graphs",
      "duration_hm": "9:43",
      "num_of_question": "0"
    },
    {
      "id": "4621",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Introduction to Single linked list",
      "duration_hm": "13:33",
      "num_of_question": "0"
    },
    {
      "id": "4648",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Representation of Graphs",
      "duration_hm": "9:55",
      "num_of_question": "0"
    },
    {
      "id": "4622",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Traversing a single linked list",
      "duration_hm": "8:16",
      "num_of_question": "0"
    },
    {
      "id": "4688",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Implementation of traversals and time and space analysis",
      "duration_hm": "21:32",
      "num_of_question": "0"
    },
    {
      "id": "4649",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Introduction to Hashing",
      "duration_hm": "17:43",
      "num_of_question": "0"
    },
    {
      "id": "4623",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Implementation of stack using arrays",
      "duration_hm": "14:55",
      "num_of_question": "0"
    },
    {
      "id": "4624",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Linked list implementation of stack",
      "duration_hm": "12:40",
      "num_of_question": "0"
    },
    {
      "id": "4653",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Introduction of BFS and DFS",
      "duration_hm": "9:9",
      "num_of_question": "0"
    },
    {
      "id": "4625",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Inserting an element in SLL",
      "duration_hm": "20:1",
      "num_of_question": "0"
    },
    {
      "id": "4692",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Double order traversal",
      "duration_hm": "12:34",
      "num_of_question": "0"
    },
    {
      "id": "4651",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Chaining",
      "duration_hm": "8:37",
      "num_of_question": "0"
    },
    {
      "id": "4664",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Open addressing",
      "duration_hm": "25:17",
      "num_of_question": "0"
    },
    {
      "id": "4627",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Deleting a node from SLL",
      "duration_hm": "18:22",
      "num_of_question": "0"
    },
    {
      "id": "4694",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Triple order traversal",
      "duration_hm": "4:40",
      "num_of_question": "0"
    },
    {
      "id": "4656",
      "cl_lecture_type": "1",
      "cl_lecture_name": "BFS algorithm",
      "duration_hm": "16:43",
      "num_of_question": "0"
    },
    {
      "id": "4626",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Implementation of a Queue using circular array",
      "duration_hm": "19:13",
      "num_of_question": "0"
    },
    {
      "id": "4666",
      "cl_lecture_type": "1",
      "cl_lecture_name": "BFS analysis in case of linked list implementation of Graph",
      "duration_hm": "6:53",
      "num_of_question": "0"
    },
    {
      "id": "4629",
      "cl_lecture_type": "1",
      "cl_lecture_name": " Implementing a queue using two stacks",
      "duration_hm": "25:37",
      "num_of_question": "0"
    },
    {
      "id": "4695",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Indirect recursion on trees",
      "duration_hm": "12:33",
      "num_of_question": "0"
    },
    {
      "id": "4668",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Linear probing",
      "duration_hm": "15:24",
      "num_of_question": "0"
    },
    {
      "id": "4630",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Printing the elements of SLL using recursion",
      "duration_hm": "11:54",
      "num_of_question": "0"
    },
    {
      "id": "4696",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Number of binary trees possible",
      "duration_hm": "5:46",
      "num_of_question": "0"
    },
    {
      "id": "4674",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Quadratic probing",
      "duration_hm": "18:33",
      "num_of_question": "0"
    },
    {
      "id": "4669",
      "cl_lecture_type": "1",
      "cl_lecture_name": "BFS analysis on adjacency matrix implementation",
      "duration_hm": "4:20",
      "num_of_question": "0"
    },
    {
      "id": "4631",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Implementing queue using one stack",
      "duration_hm": "5:25",
      "num_of_question": "0"
    },
    {
      "id": "4634",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Infix to postfix conversion algorithm",
      "duration_hm": "22:52",
      "num_of_question": "0"
    },
    {
      "id": "4699",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Number of binary trees possible labelled and unlabelled",
      "duration_hm": "19:43",
      "num_of_question": "0"
    },
    {
      "id": "4671",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Breadth First Traversal using BFS",
      "duration_hm": "8:27",
      "num_of_question": "0"
    },
    {
      "id": "4632",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Reversing an SLL using iterative program",
      "duration_hm": "14:0",
      "num_of_question": "0"
    },
    {
      "id": "4678",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Double hashing",
      "duration_hm": "11:57",
      "num_of_question": "0"
    },
    {
      "id": "4637",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Postfix evaluation algorithm",
      "duration_hm": "8:55",
      "num_of_question": "0"
    },
    {
      "id": "4675",
      "cl_lecture_type": "1",
      "cl_lecture_name": "DFS algorithm",
      "duration_hm": "15:24",
      "num_of_question": "0"
    },
    {
      "id": "4635",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Recursive program for reversing an SLL",
      "duration_hm": "15:19",
      "num_of_question": "0"
    },
    {
      "id": "4700",
      "cl_lecture_type": "1",
      "cl_lecture_name": "construction of unique binary tree using In order and preorder",
      "duration_hm": "14:31",
      "num_of_question": "0"
    },
    {
      "id": "4636",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Circular linked list",
      "duration_hm": "4:12",
      "num_of_question": "0"
    },
    {
      "id": "4702",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Recursive program to count the number of nodes",
      "duration_hm": "14:46",
      "num_of_question": "0"
    },
    {
      "id": "4679",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Analysis of DFS and DFT",
      "duration_hm": "6:47",
      "num_of_question": "0"
    },
    {
      "id": "4703",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Recursive program to count the number of leaves and non leaves",
      "duration_hm": "15:56",
      "num_of_question": "0"
    },
    {
      "id": "4680",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Introduction to Topological Sort",
      "duration_hm": "4:3",
      "num_of_question": "0"
    },
    {
      "id": "4641",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Insertion into doubly linked list",
      "duration_hm": "12:7",
      "num_of_question": "0"
    },
    {
      "id": "4706",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Recursive program to find the full nodes",
      "duration_hm": "18:55",
      "num_of_question": "0"
    },
    {
      "id": "4682",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Algorithm for topological sort (Approach-1)",
      "duration_hm": "5:32",
      "num_of_question": "0"
    },
    {
      "id": "4708",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Recursive program to find the height of a tree",
      "duration_hm": "12:9",
      "num_of_question": "0"
    },
    {
      "id": "4683",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Algorithm for topological sort (Approach 2)",
      "duration_hm": "7:28",
      "num_of_question": "0"
    },
    {
      "id": "4709",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Introduction to BST",
      "duration_hm": "9:21",
      "num_of_question": "0"
    },
    {
      "id": "4713",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Deleting a node from BST",
      "duration_hm": "12:9",
      "num_of_question": "0"
    },
    {
      "id": "4726",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Data Structure for Disjoint Sets",
      "duration_hm": "3:32",
      "num_of_question": "0"
    },
    {
      "id": "4715",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Finding minimum and maximum in a BST",
      "duration_hm": "10:15",
      "num_of_question": "0"
    },
    {
      "id": "4716",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Leaves in complete n-ary tree GATE 98 question",
      "duration_hm": "10:42",
      "num_of_question": "0"
    },
    {
      "id": "4727",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Operations on Disjoint Sets",
      "duration_hm": "4:42",
      "num_of_question": "0"
    },
    {
      "id": "4717",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Leaves in complete n-ary tree 2002 question",
      "duration_hm": "4:42",
      "num_of_question": "0"
    },
    {
      "id": "4728",
      "cl_lecture_type": "1",
      "cl_lecture_name": " Linked list representation of disjoint sets",
      "duration_hm": "5:10",
      "num_of_question": "0"
    },
    {
      "id": "4729",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Time complexity for linked list representation of Disjoint Sets",
      "duration_hm": "5:21",
      "num_of_question": "0"
    },
    {
      "id": "4718",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Recursive program on testing whether a tree is complete binary tree",
      "duration_hm": "10:17",
      "num_of_question": "0"
    },
    {
      "id": "4719",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Expression trees",
      "duration_hm": "8:56",
      "num_of_question": "0"
    },
    {
      "id": "4730",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Amortized analysis of disjoint sets using linked list representation",
      "duration_hm": "6:37",
      "num_of_question": "0"
    },
    {
      "id": "4731",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Disjoint set forest",
      "duration_hm": "4:47",
      "num_of_question": "0"
    },
    {
      "id": "4720",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Various tree representations",
      "duration_hm": "13:29",
      "num_of_question": "0"
    },
    {
      "id": "4732",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Union by rank",
      "duration_hm": "2:37",
      "num_of_question": "0"
    },
    {
      "id": "4733",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Analysis union by rank",
      "duration_hm": "11:15",
      "num_of_question": "0"
    },
    {
      "id": "4734",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Path compression",
      "duration_hm": "6:14",
      "num_of_question": "0"
    },
    {
      "id": "4735",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Time complexity using the Heuristics",
      "duration_hm": "5:31",
      "num_of_question": "0"
    },
    {
      "id": "4736",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Kruskal's algorithm using Disjoint sets",
      "duration_hm": "7:13",
      "num_of_question": "0"
    },
    {
      "id": "4737",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Example on kruskal's using Disjoint sets",
      "duration_hm": "8:53",
      "num_of_question": "0"
    },
    {
      "id": "4738",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Connected components using Disjoints",
      "duration_hm": "4:47",
      "num_of_question": "0"
    },
    {
      "id": "4739",
      "cl_lecture_type": "1",
      "cl_lecture_name": "Example on connected components using Disjoint sets",
      "duration_hm": "4:55",
      "num_of_question": "0"
    }
  ]
}

# %%
lectures = json1["lectures"]

# %%
lectures_list = sorted(lectures, key=lambda k: k['id'])

# %%
ll = []
for i in lectures_list:
    ll.append(i['cl_lecture_name'])

# %%
ll
# Out:
# ['Introduction to stacks',
#  'Introduction to Single linked list',
#  'Traversing a single linked list',
#  'Implementation of stack using arrays',
#  'Linked list implementation of stack',
#  'Inserting an element in SLL',
#  'Implementation of a Queue using circular array',
#  'Deleting a node from SLL',
#  ' Implementing a queue using two stacks',
#  'Printing the elements of SLL using recursion',
#  'Implementing queue using one stack',
#  'Reversing an SLL using iterative program',
#  'Infix to postfix conversion algorithm',
#  'Recursive program for reversing an SLL',
#  'Circular linked list',
#  'Postfix evaluation algorithm',
#  'Insertion into doubly linked list',
#  'Direct Address Table',
#  'Introduction to Graphs',
#  'Representation of Graphs',
#  'Introduction to Hashing',
#  'Chaining',
#  'Introduction of BFS and DFS',
#  'BFS algorithm',
#  'Open addressing',
#  'BFS analysis in case of linked list implementation of Graph',
#  'Linear probing',
# ...

# %%
for i in ll:
    if 'disjoin' in i or 'Disjoint' in i or 'Union' in i or 'union' in i or 'Heu' in i or 'compression' in i:
        print(i)
# Out:
# Data Structure for Disjoint Sets
# Operations on Disjoint Sets
#  Linked list representation of disjoint sets
# Time complexity for linked list representation of Disjoint Sets
# Amortized analysis of disjoint sets using linked list representation
# Disjoint set forest
# Union by rank
# Analysis union by rank
# Path compression
# Time complexity using the Heuristics
# Kruskal's algorithm using Disjoint sets
# Example on kruskal's using Disjoint sets
# Connected components using Disjoints
# Example on connected components using Disjoint sets

# %%
json2 = {"success":True,"lectures":[{"id":"947","cl_lecture_type":"1","cl_lecture_name":"matrix multiplication","duration_hm":"5:53","num_of_question":"0"},{"id":"896","cl_lecture_type":"1","cl_lecture_name":"Dijkstra algorithm example1","duration_hm":"17:56","num_of_question":"0"},{"id":"1202","cl_lecture_type":"1","cl_lecture_name":"Introduction to LCS","duration_hm":"17:22","num_of_question":"0"},{"id":"4287","cl_lecture_type":"4","cl_lecture_name":"Insertion sort algorithm and analysis","duration_hm":"27:38","num_of_question":"0"},{"id":"6330","cl_lecture_type":"5","cl_lecture_name":"Read Me First","duration_hm":"0:0","num_of_question":"0"},{"id":"1101","cl_lecture_type":"1","cl_lecture_name":"Introduction to multi stage graph","duration_hm":"8:10","num_of_question":"0"},{"id":"901","cl_lecture_type":"1","cl_lecture_name":"Introduction to Greedy algorithms","duration_hm":"7:8","num_of_question":"0"},{"id":"933","cl_lecture_type":"1","cl_lecture_name":"Introduction to Dynamic programming","duration_hm":"13:1","num_of_question":"0"},{"id":"1203","cl_lecture_type":"1","cl_lecture_name":"Introduction","duration_hm":"6:7","num_of_question":"0"},{"id":"1131","cl_lecture_type":"1","cl_lecture_name":"Introduction to TSP","duration_hm":"6:47","num_of_question":"0"},{"id":"1158","cl_lecture_type":"1","cl_lecture_name":"Difference between fractional and 0-1 knapsack","duration_hm":"8:24","num_of_question":"0"},{"id":"993","cl_lecture_type":"1","cl_lecture_name":"Subset Sum Introduction","duration_hm":"11:28","num_of_question":"0"},{"id":"1201","cl_lecture_type":"1","cl_lecture_name":"Relationship between single source shortest path and all pairs shortest path","duration_hm":"5:15","num_of_question":"0"},{"id":"4281","cl_lecture_type":"4","cl_lecture_name":"Algorithms Lecture 1 -- Introduction to asymptotic notations","duration_hm":"22:27","num_of_question":"0"},{"id":"1163","cl_lecture_type":"1","cl_lecture_name":"Why greedy method fails in 0-1 knapsack","duration_hm":"3:18","num_of_question":"0"},{"id":"907","cl_lecture_type":"1","cl_lecture_name":"Dijkstra algorithm example2","duration_hm":"4:38","num_of_question":"0"},{"id":"1205","cl_lecture_type":"1","cl_lecture_name":"Optimal substructure","duration_hm":"6:52","num_of_question":"0"},{"id":"928","cl_lecture_type":"1","cl_lecture_name":"Greedy knap sack algorithm","duration_hm":"32:23","num_of_question":"0"},{"id":"1114","cl_lecture_type":"1","cl_lecture_name":"Substructure and recursive equation","duration_hm":"9:35","num_of_question":"0"},{"id":"4282","cl_lecture_type":"4","cl_lecture_name":"Time complexity Analysis of iterative programs","duration_hm":"37:9","num_of_question":"0"},{"id":"952","cl_lecture_type":"1","cl_lecture_name":"chain multiplication introduction","duration_hm":"5:4","num_of_question":"0"},{"id":"1206","cl_lecture_type":"1","cl_lecture_name":"Optimal substructure and Recursive equations","duration_hm":"10:8","num_of_question":"0"},{"id":"1068","cl_lecture_type":"1","cl_lecture_name":"Example","duration_hm":"21:23","num_of_question":"0"},{"id":"4288","cl_lecture_type":"4","cl_lecture_name":"Merge sort algorithm, analysis and problems","duration_hm":"65:9","num_of_question":"0"},{"id":"1207","cl_lecture_type":"1","cl_lecture_name":"Types of algorithms","duration_hm":"10:37","num_of_question":"0"},{"id":"1150","cl_lecture_type":"1","cl_lecture_name":"Detecting Optimal substructure","duration_hm":"18:53","num_of_question":"0"},{"id":"1077","cl_lecture_type":"1","cl_lecture_name":"Huffman codes","duration_hm":"42:59","num_of_question":"0"},{"id":"1215","cl_lecture_type":"1","cl_lecture_name":"Recursion tree and unique sub problems","duration_hm":"28:30","num_of_question":"0"},{"id":"4289","cl_lecture_type":"4","cl_lecture_name":"Quick sort algorithm","duration_hm":"44:51","num_of_question":"0"},{"id":"1016","cl_lecture_type":"1","cl_lecture_name":"Examples","duration_hm":"15:47","num_of_question":"0"},{"id":"1210","cl_lecture_type":"1","cl_lecture_name":"some examples","duration_hm":"6:16","num_of_question":"0"},{"id":"1155","cl_lecture_type":"1","cl_lecture_name":"Bottom up dynamic programming algorithm","duration_hm":"22:55","num_of_question":"0"},{"id":"916","cl_lecture_type":"1","cl_lecture_name":"Dijkstra algorithm","duration_hm":"11:40","num_of_question":"0"},{"id":"4283","cl_lecture_type":"4","cl_lecture_name":" Time analysis of recursive program","duration_hm":"24:37","num_of_question":"0"},{"id":"1166","cl_lecture_type":"1","cl_lecture_name":"Substructure and Recursive equation","duration_hm":"7:44","num_of_question":"0"},{"id":"1127","cl_lecture_type":"1","cl_lecture_name":"Bottom up Dynamic programming algorithm","duration_hm":"18:40","num_of_question":"0"},{"id":"1218","cl_lecture_type":"1","cl_lecture_name":"Example","duration_hm":"33:7","num_of_question":"0"},{"id":"1098","cl_lecture_type":"1","cl_lecture_name":"Optimal substructure and Recursive equations","duration_hm":"12:53","num_of_question":"0"},{"id":"4284","cl_lecture_type":"4","cl_lecture_name":"comparing various functions to analyse time complexity","duration_hm":"25:26","num_of_question":"0"},{"id":"1223","cl_lecture_type":"1","cl_lecture_name":"Time complexity and space complexity of bottom up dynamic programming algorithm","duration_hm":"5:30","num_of_question":"0"},{"id":"1219","cl_lecture_type":"1","cl_lecture_name":"example 1","duration_hm":"8:15","num_of_question":"0"},{"id":"4290","cl_lecture_type":"4","cl_lecture_name":"Analysis of quick sort and problems on it","duration_hm":"32:52","num_of_question":"0"},{"id":"1169","cl_lecture_type":"1","cl_lecture_name":"Recursion tree and unique subproblems","duration_hm":"9:4","num_of_question":"0"},{"id":"1090","cl_lecture_type":"1","cl_lecture_name":"More examples on Huffman codes","duration_hm":"12:8","num_of_question":"0"},{"id":"1213","cl_lecture_type":"1","cl_lecture_name":"Optimisation and Decision problems","duration_hm":"14:25","num_of_question":"0"},{"id":"926","cl_lecture_type":"1","cl_lecture_name":"Negative weight edges and dijkstra algorithm","duration_hm":"18:12","num_of_question":"0"},{"id":"1226","cl_lecture_type":"1","cl_lecture_name":"Bottom Dynamic programming algorithm","duration_hm":"3:38","num_of_question":"0"},{"id":"4291","cl_lecture_type":"4","cl_lecture_name":"introduction to heaps","duration_hm":"39:43","num_of_question":"0"},{"id":"1172","cl_lecture_type":"1","cl_lecture_name":"Example tracing out bottom up Dynamic programming algorithm","duration_hm":"22:51","num_of_question":"0"},{"id":"1216","cl_lecture_type":"1","cl_lecture_name":"We use only decision problems in NP completeness theory","duration_hm":"5:6","num_of_question":"0"},{"id":"4285","cl_lecture_type":"4","cl_lecture_name":"Masters theorem","duration_hm":"24:38","num_of_question":"0"},{"id":"1224","cl_lecture_type":"1","cl_lecture_name":"example 2","duration_hm":"12:14","num_of_question":"0"},{"id":"1115","cl_lecture_type":"1","cl_lecture_name":"Recursion tree","duration_hm":"13:47","num_of_question":"0"},{"id":"1113","cl_lecture_type":"1","cl_lecture_name":"Job sequencing with deadlines","duration_hm":"22:32","num_of_question":"0"},{"id":"1227","cl_lecture_type":"1","cl_lecture_name":"Bottom up Dynamic programming algorithm","duration_hm":"4:34","num_of_question":"0"},{"id":"4292","cl_lecture_type":"4","cl_lecture_name":" Max heapify algorithm and complete binary tree","duration_hm":"37:37","num_of_question":"0"},{"id":"1124","cl_lecture_type":"1","cl_lecture_name":"Dynamic programming bottom up implementation","duration_hm":"28:30","num_of_question":"0"},{"id":"5261","cl_lecture_type":"5","cl_lecture_name":"Optimal merge Patterns video mistake at 10:03 mins","duration_hm":"0:0","num_of_question":"0"},{"id":"1221","cl_lecture_type":"1","cl_lecture_name":"Verfication algorithms","duration_hm":"8:51","num_of_question":"0"},{"id":"1176","cl_lecture_type":"1","cl_lecture_name":"Bottom up Dynamic programming algorithm and analysis","duration_hm":"6:51","num_of_question":"0"},{"id":"4286","cl_lecture_type":"4","cl_lecture_name":"Analyzing Space complexity of iterative and recursive algorithms","duration_hm":"46:15","num_of_question":"0"},{"id":"5585","cl_lecture_type":"5","cl_lecture_name":"Note","duration_hm":"0:0","num_of_question":"0"},{"id":"1118","cl_lecture_type":"1","cl_lecture_name":"Optimal merge patterns","duration_hm":"13:42","num_of_question":"0"},{"id":"1130","cl_lecture_type":"1","cl_lecture_name":"Top down dynamic programming memoization algorithm","duration_hm":"10:27","num_of_question":"0"},{"id":"1228","cl_lecture_type":"1","cl_lecture_name":"P NP Introduction","duration_hm":"14:39","num_of_question":"0"},{"id":"4293","cl_lecture_type":"4","cl_lecture_name":"Build max heap algorithm and analysis","duration_hm":"15:24","num_of_question":"0"},{"id":"1132","cl_lecture_type":"1","cl_lecture_name":"Introduction to spanning trees and Kirchhoff theorem","duration_hm":"37:3","num_of_question":"0"},{"id":"1237","cl_lecture_type":"1","cl_lecture_name":"Polynomial time reduction algorithms","duration_hm":"19:9","num_of_question":"0"},{"id":"1078","cl_lecture_type":"1","cl_lecture_name":"Amortized Analysis","duration_hm":"2:37","num_of_question":"0"},{"id":"1159","cl_lecture_type":"1","cl_lecture_name":"MST and examples on prims algorithm","duration_hm":"42:21","num_of_question":"0"},{"id":"1146","cl_lecture_type":"1","cl_lecture_name":"Heap sort and analysis","duration_hm":"16:44","num_of_question":"0"},{"id":"1246","cl_lecture_type":"1","cl_lecture_name":"NP hard and NP complete problems","duration_hm":"23:44","num_of_question":"0"},{"id":"1082","cl_lecture_type":"1","cl_lecture_name":"Aggregate Analysis","duration_hm":"3:32","num_of_question":"0"},{"id":"1251","cl_lecture_type":"1","cl_lecture_name":"Well know NP complete problems","duration_hm":"12:12","num_of_question":"0"},{"id":"1167","cl_lecture_type":"1","cl_lecture_name":"Prims algorithm implementation without min heap","duration_hm":"28:51","num_of_question":"0"},{"id":"1089","cl_lecture_type":"1","cl_lecture_name":"Example on Aggregate Analysis","duration_hm":"7:5","num_of_question":"0"},{"id":"1198","cl_lecture_type":"1","cl_lecture_name":"Prims algorithm implement with min heap","duration_hm":"29:20","num_of_question":"0"},{"id":"1181","cl_lecture_type":"1","cl_lecture_name":"Introduction to kruskal algorithm and examples on it","duration_hm":"40:30","num_of_question":"0"},{"id":"2172","cl_lecture_type":"1","cl_lecture_name":"Kruskal's algorithm using Disjoint sets","duration_hm":"7:13","num_of_question":"0"},{"id":"1162","cl_lecture_type":"1","cl_lecture_name":"Bubble sort algorithm","duration_hm":"6:15","num_of_question":"0"},{"id":"1165","cl_lecture_type":"1","cl_lecture_name":"Example on Bubble sort","duration_hm":"8:49","num_of_question":"0"},{"id":"2174","cl_lecture_type":"1","cl_lecture_name":"Example on kruskal's using Disjoint sets","duration_hm":"8:53","num_of_question":"0"},{"id":"1170","cl_lecture_type":"1","cl_lecture_name":"Time complenity analysis for bubble sort","duration_hm":"5:37","num_of_question":"0"},{"id":"1183","cl_lecture_type":"1","cl_lecture_name":"Amortized Analysis","duration_hm":"2:37","num_of_question":"0"},{"id":"1188","cl_lecture_type":"1","cl_lecture_name":"Aggregate Analysis","duration_hm":"3:32","num_of_question":"0"},{"id":"1190","cl_lecture_type":"1","cl_lecture_name":"Example on Aggregate Analysis","duration_hm":"7:5","num_of_question":"0"},{"id":"2156","cl_lecture_type":"1","cl_lecture_name":"Data Structure for Disjoint Sets","duration_hm":"3:32","num_of_question":"0"},{"id":"4294","cl_lecture_type":"4","cl_lecture_name":"Extract max, increase key and insert key into heap","duration_hm":"22:11","num_of_question":"0"},{"id":"2157","cl_lecture_type":"1","cl_lecture_name":"Operations on Disjoint Sets","duration_hm":"4:42","num_of_question":"0"},{"id":"2159","cl_lecture_type":"1","cl_lecture_name":" Linked list representation of disjoint sets","duration_hm":"5:10","num_of_question":"0"},{"id":"2161","cl_lecture_type":"1","cl_lecture_name":"Time complexity for linked list representation of Disjoint Sets","duration_hm":"5:21","num_of_question":"0"},{"id":"2162","cl_lecture_type":"1","cl_lecture_name":"Amortized analysis of disjoint sets using linked list representation","duration_hm":"6:37","num_of_question":"0"},{"id":"2164","cl_lecture_type":"1","cl_lecture_name":"Disjoint set forest","duration_hm":"4:47","num_of_question":"0"},{"id":"1191","cl_lecture_type":"1","cl_lecture_name":"Bucket sort","duration_hm":"6:20","num_of_question":"0"},{"id":"1193","cl_lecture_type":"1","cl_lecture_name":"Counting sort","duration_hm":"5:43","num_of_question":"0"},{"id":"2166","cl_lecture_type":"1","cl_lecture_name":"Union by rank","duration_hm":"2:37","num_of_question":"0"},{"id":"2168","cl_lecture_type":"1","cl_lecture_name":"Analysis union by rank","duration_hm":"11:15","num_of_question":"0"},{"id":"1195","cl_lecture_type":"1","cl_lecture_name":"Radix-sort(aid)","duration_hm":"7:31","num_of_question":"0"},{"id":"1197","cl_lecture_type":"1","cl_lecture_name":"Analysis of time complexity on radix -sort(AID)","duration_hm":"8:12","num_of_question":"0"},{"id":"2170","cl_lecture_type":"1","cl_lecture_name":"Path compression","duration_hm":"6:14","num_of_question":"0"},{"id":"2171","cl_lecture_type":"1","cl_lecture_name":"Time complexity using the Heuristics","duration_hm":"5:31","num_of_question":"0"},{"id":"2179","cl_lecture_type":"1","cl_lecture_name":"Algorithm of selection sort file","duration_hm":"3:43","num_of_question":"0"},{"id":"2176","cl_lecture_type":"1","cl_lecture_name":"Connected components using Disjoints","duration_hm":"4:47","num_of_question":"0"},{"id":"2180","cl_lecture_type":"1","cl_lecture_name":"Analysis of selection sort file","duration_hm":"13:36","num_of_question":"0"},{"id":"2178","cl_lecture_type":"1","cl_lecture_name":"Example on connected components using Disjoint sets","duration_hm":"4:55","num_of_question":"0"}]}

# %%
lectures = json2["lectures"]

# %%
lectures
# Out:
# [{'cl_lecture_name': 'matrix multiplication',
#   'cl_lecture_type': '1',
#   'duration_hm': '5:53',
#   'id': '947',
#   'num_of_question': '0'},
#  {'cl_lecture_name': 'Dijkstra algorithm example1',
#   'cl_lecture_type': '1',
#   'duration_hm': '17:56',
#   'id': '896',
#   'num_of_question': '0'},
#  {'cl_lecture_name': 'Introduction to LCS',
#   'cl_lecture_type': '1',
#   'duration_hm': '17:22',
#   'id': '1202',
#   'num_of_question': '0'},
#  {'cl_lecture_name': 'Insertion sort algorithm and analysis',
#   'cl_lecture_type': '4',
#   'duration_hm': '27:38',
#   'id': '4287',
#   'num_of_question': '0'},
#  {'cl_lecture_name': 'Read Me First',
#   'cl_lecture_type': '5',
#   'duration_hm': '0:0',
#   'id': '6330',
#   'num_of_question': '0'},
#  {'cl_lecture_name': 'Introduction to multi stage graph',
#   'cl_lecture_type': '1',
#   'duration_hm': '8:10',
#   'id': '1101',
#   'num_of_question': '0'},
#  {'cl_lecture_name': 'Introduction to Greedy algorithms',
# ...

# %%
lectures_list = sorted(lectures, key=lambda k: k['id'])

# %%
ll = []
for i in lectures_list:
    ll.append(i['cl_lecture_name'])

# %%
ll
# Out:
# ['Examples',
#  'Example',
#  'Huffman codes',
#  'Amortized Analysis',
#  'Aggregate Analysis',
#  'Example on Aggregate Analysis',
#  'More examples on Huffman codes',
#  'Optimal substructure and Recursive equations',
#  'Introduction to multi stage graph',
#  'Job sequencing with deadlines',
#  'Substructure and recursive equation',
#  'Recursion tree',
#  'Optimal merge patterns',
#  'Dynamic programming bottom up implementation',
#  'Bottom up Dynamic programming algorithm',
#  'Top down dynamic programming memoization algorithm',
#  'Introduction to TSP',
#  'Introduction to spanning trees and Kirchhoff theorem',
#  'Heap sort and analysis',
#  'Detecting Optimal substructure',
#  'Bottom up dynamic programming algorithm',
#  'Difference between fractional and 0-1 knapsack',
#  'MST and examples on prims algorithm',
#  'Bubble sort algorithm',
#  'Why greedy method fails in 0-1 knapsack',
#  'Example on Bubble sort',
#  'Substructure and Recursive equation',
# ...

# %%
for i in ll:
    if 'Dynamic programming' in i :#or 'dijkstra' in i or 'Disjoint' in i or 'disjoint' in i or 'compression' in i or 'rank' in i or 'Heur' in i or 'components' in i:
        print(i)
# Out:
# Dynamic programming bottom up implementation
# Bottom up Dynamic programming algorithm
# Example tracing out bottom up Dynamic programming algorithm
# Bottom up Dynamic programming algorithm and analysis
# Bottom Dynamic programming algorithm
# Bottom up Dynamic programming algorithm
# Introduction to Dynamic programming

# %%
html_str = '''<div class="changed-container-for-forum" id="curriculum_div"><div class="curriculam-container"><div class="curriculam-title"><h4>Instruction Note</h4></div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/6330">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon code-grey"></span>
                </span>
                
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Read Me First</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="curriculam-title"><h4>Time and Space analysis</h4></div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/4281">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Algorithms Lecture 1 -- Introduction to asymptotic notations</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">22 : 27</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/4282">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Time complexity Analysis of iterative programs</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">37 : 09</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/4283">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold"> Time analysis of recursive program</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">24 : 37</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/4284">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">comparing various functions to analyse time complexity</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">25 : 26</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/4285">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Masters theorem</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">24 : 38</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/4286">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Analyzing Space complexity of iterative and recursive algorithms</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">46 : 15</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/5585">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon code-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Note</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1078">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Amortized Analysis</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 37</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1082">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Aggregate Analysis</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 32</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1089">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Example on Aggregate Analysis</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 05</p>
                                    </div>
                                </a>
                            </div><div class="curriculam-title"><h4>Sorting Techniques</h4></div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/4287">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-blue"></span>
                </span>
                <div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Insertion sort algorithm and analysis</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">27 : 38</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/4288">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-blue"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Merge sort algorithm, analysis and problems</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">65 : 09</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/4289">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-blue"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Quick sort algorithm</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">44 : 51</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/4290">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-blue"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Analysis of quick sort and problems on it</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">32 : 52</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/4291">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-blue"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">introduction to heaps</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">39 : 43</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/4292">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-blue"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold"> Max heapify algorithm and complete binary tree</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">37 : 37</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/4293">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Build max heap algorithm and analysis</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">15 : 24</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1146">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-blue"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Heap sort and analysis</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">16 : 44</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1162">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Bubble sort algorithm</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 15</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1165">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Example on Bubble sort</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">08 : 49</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1170">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Time complenity analysis for bubble sort</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 37</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/4294">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-blue"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Extract max, increase key and insert key into heap</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">22 : 11</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1191">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-blue"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Bucket sort</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 20</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1193">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Counting sort</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 43</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1195">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-blue"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Radix-sort(aid)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 31</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1197">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Analysis of time complexity on radix -sort(AID)</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">08 : 12</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/2179">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Algorithm of selection sort file</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 43</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/2180">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Analysis of selection sort file</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">13 : 36</p>
                                    </div>
                                </a>
                            </div><div class="curriculam-title"><h4>Greedy algorithms</h4></div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/901">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-blue"></span>
                </span>
                <div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Introduction to Greedy algorithms</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 08</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/928">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-blue"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Greedy knap sack algorithm</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">32 : 23</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1077">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-blue"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Huffman codes</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">42 : 59</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1090">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">More examples on Huffman codes</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">12 : 08</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1113">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-blue"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Job sequencing with deadlines</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">22 : 32</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/5261">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon code-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Optimal merge Patterns video mistake at 10:03 mins</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1118">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Optimal merge patterns</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">13 : 42</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1132">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-blue"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Introduction to spanning trees and Kirchhoff theorem</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">37 : 03</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1159">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-blue"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">MST and examples on prims algorithm</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">42 : 21</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1167">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Prims algorithm implementation without min heap</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">28 : 51</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1198">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Prims algorithm implement with min heap</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">29 : 20</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1181">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-blue"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Introduction to kruskal algorithm and examples on it</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">40 : 30</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/2172">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Kruskal's algorithm using Disjoint sets</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 13</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/2174">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Example on kruskal's using Disjoint sets</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">08 : 53</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1183">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Amortized Analysis</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 37</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1188">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Aggregate Analysis</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 32</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1190">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Example on Aggregate Analysis</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 05</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/2156">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Data Structure for Disjoint Sets</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 32</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/2157">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Operations on Disjoint Sets</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 42</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/2159">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold"> Linked list representation of disjoint sets</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 10</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/2161">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Time complexity for linked list representation of Disjoint Sets</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 21</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/2162">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Amortized analysis of disjoint sets using linked list representation</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 37</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/2164">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Disjoint set forest</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 47</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/2166">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Union by rank</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 37</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/2168">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Analysis union by rank</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">11 : 15</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/2170">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Path compression</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 14</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/2171">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Time complexity using the Heuristics</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 31</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/2176">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-blue"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Connected components using Disjoints</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 47</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/2178">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Example on connected components using Disjoint sets</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 55</p>
                                    </div>
                                </a>
                            </div><div class="curriculam-title"><h4>Dijkstra Algorithm</h4></div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/896">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Dijkstra algorithm example1</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">17 : 56</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/907">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Dijkstra algorithm example2</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 38</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/916">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Dijkstra algorithm</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">11 : 40</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/926">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Negative weight edges and dijkstra algorithm</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">18 : 12</p>
                                    </div>
                                </a>
                            </div><div class="curriculam-title"><h4>Dynamic programming</h4></div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/933">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Introduction to Dynamic programming</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">13 : 01</p>
                                    </div>
                                </a>
                            </div><div class="curriculam-title"><h4>Matrix chain multiplication -- Dynamic Programming</h4></div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/947">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">matrix multiplication</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 53</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/952">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">chain multiplication introduction</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 04</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1016">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Examples</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">15 : 47</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1098">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Optimal substructure and Recursive equations</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">12 : 53</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1115">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Recursion tree</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">13 : 47</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1124">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Dynamic programming bottom up implementation</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">28 : 30</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1130">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Top down dynamic programming memoization algorithm</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">10 : 27</p>
                                    </div>
                                </a>
                            </div><div class="curriculam-title"><h4>Longest common subsequence</h4></div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1202">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Introduction to LCS</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">17 : 22</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1206">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Optimal substructure and Recursive equations</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">10 : 08</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1215">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Recursion tree and unique sub problems</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">28 : 30</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1219">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">example 1</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">08 : 15</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1224">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">example 2</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">12 : 14</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1227">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Bottom up Dynamic programming algorithm</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 34</p>
                                    </div>
                                </a>
                            </div><div class="curriculam-title"><h4>Multi stage graph</h4></div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1101">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Introduction to multi stage graph</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">08 : 10</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1114">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Substructure and recursive equation</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">09 : 35</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1127">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Bottom up Dynamic programming algorithm</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">18 : 40</p>
                                    </div>
                                </a>
                            </div><div class="curriculam-title"><h4>0/1 Knapsack</h4></div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1158">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Difference between fractional and 0-1 knapsack</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">08 : 24</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1163">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Why greedy method fails in 0-1 knapsack</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 18</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1166">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Substructure and Recursive equation</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 44</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1169">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Recursion tree and unique subproblems</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">09 : 04</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1172">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Example tracing out bottom up Dynamic programming algorithm</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">22 : 51</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1176">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Bottom up Dynamic programming algorithm and analysis</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 51</p>
                                    </div>
                                </a>
                            </div><div class="curriculam-title"><h4>Subset sum</h4></div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/993">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Subset Sum Introduction</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">11 : 28</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1068">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Example</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">21 : 23</p>
                                    </div>
                                </a>
                            </div><div class="curriculam-title"><h4>Travelling salesman problem</h4></div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1131">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Introduction to TSP</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 47</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1150">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Detecting Optimal substructure</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">18 : 53</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1155">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Bottom up dynamic programming algorithm</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">22 : 55</p>
                                    </div>
                                </a>
                            </div><div class="curriculam-title"><h4>All pairs shortest path -- Floyd Warshall</h4></div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1201">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Relationship between single source shortest path and all pairs shortest path</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 15</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1205">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Optimal substructure</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 52</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1218">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Example</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">33 : 07</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1223">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Time complexity and space complexity of bottom up dynamic programming algorithm</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 30</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1226">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Bottom Dynamic programming algorithm</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 38</p>
                                    </div>
                                </a>
                            </div><div class="curriculam-title"><h4>NP Completeness (Not required for GATE) Complexity Classes</h4></div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1203">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Introduction</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 07</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1207">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Types of algorithms</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">10 : 37</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1210">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">some examples</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 16</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1213">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Optimisation and Decision problems</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">14 : 25</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1216">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">We use only decision problems in NP completeness theory</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 06</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1221">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Verfication algorithms</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">08 : 51</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1228">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">P NP Introduction</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">14 : 39</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1237">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Polynomial time reduction algorithms</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">19 : 09</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1246">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">NP hard and NP complete problems</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">23 : 44</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/7/1251">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Well know NP complete problems</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">12 : 12</p>
                                    </div>
                                </a>
                            </div></div></div>'''

# %%
html_str = '''<div class="curriculam-container"><div class="curriculam-title"><h4>Arrays</h4></div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3139">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of Linear search</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">11 : 04</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3141">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-blue"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of Binary search</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">08 : 43</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3143">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-blue"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find a pair in an array whose sum is equal to given number</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 13</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3144">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find a pair in an array whose sum is equal to given number (Hash Approach)</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 27</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3145">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation to print all pairs in an array whose sum is X</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">09 : 30</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3978">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon document-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find a pair whose sum is X (Hash approach)File</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 2 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3979">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon document-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find a pair whose sum is x File</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3146">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Finding majority element approach-1 using linear search</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 31</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3147">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-blue"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Moore voting algorithm</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">14 : 12</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3980">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon document-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Moore Voting Algorithm File</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3149">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">implementation of finding the majority element in the given array</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">09 : 42</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3150">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the maximum difference between two elements in an array such that larger element appears after the smaller number (Approach-1)</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 00</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3152">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the max difference in an array so that the larger element has higher index than smaller element Approach-2</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">08 : 55</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3154">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the maximum difference between two elements in an array such that larger element appears after the smaller number (Approach-3)</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 44</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3155">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-blue"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of maximum difference b/w two elements in an array such that larger element has higher index than smaller element</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">10 : 37</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3981">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon document-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the maximum difference between two elements such that larger element appears after the smaller element File</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3156">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the number occurring odd number of times in a given array of size 'n'</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 34</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3157">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of finding the number occurring odd number of times in given array</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 32</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3982">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon document-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the number occurring odd number of times in a given array of size 'n'</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3159">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Separate 0's and 1's in an array ( Approach-1)</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 40</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3160">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Separate 0's and 1's in an array (Approach-2)</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 40</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3161">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of separate 0's and 1's in an array</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 00</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3983">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon document-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Separate 0's and 1's in an array File</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3176">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-blue"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Given an array A, Find two elements whose sum is closest to zero</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 03</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3179">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation for finding the pair in the given array whose sum is closest to Zero</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">10 : 34</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3984">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon document-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">sum of two elements closest to zero File</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3181">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find a triplet in given array that sum to given value 'x' Approach-1</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 09</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3190">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find a triplet in given array that sum to given value 'x' Approach-2</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 15</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3191">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-blue"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation for find a triplet that sum to a given value</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">10 : 57</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3985">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Given an array A, Find three element such that their sum is equal to X File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3192">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the equilibrium index in an array</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 42</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3193">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation for equlibrium index in an array</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 55</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3986">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon document-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the equilibrium index in an array File</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3194">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Given an array of size unknown with all 0's in the beginning and 1's in the end. Find the starting index of 1</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 10</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3195">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Given an array and an integer k, find the maximum for each and every contiguous sub array of size k Approach-1</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 3 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 52</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3196">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Given an array and an integer k, find the maximum for each and every contiguous sub array of size k Approach-2</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 3 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 59</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3197">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Given an array and an integer k, find the maximum for each and every contiguous sub array of size k Approach-3</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">10 : 28</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3198">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-blue"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">implementation of Given an array and an integer k, find the maximum for each and every contiguous sub array of size</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 37</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3987">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Given an array and an integer k, find the maximum element for each and every contiguous sub array of size</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3199">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Count number of smaller elements on right of each element in an array</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">10 : 40</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3200">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of count number of smaller elements on right of each element in an array</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">01 : 31</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3988">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Count smaller elements on right side File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3207">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the largest multiple of 3</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 03</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3209">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of Find max multiple of 3</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">08 : 48</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3989">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">C code for largest multiple of 3 File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3263">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the sub array with given sum X (Approach-1)</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">11 : 41</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3264">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the sub array with given sum X (Approach-2)</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 51</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3266">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the sub array with given sum zero (Approach-3)</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">01 : 15</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3265">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of find the subarray with given sum'x'</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 09</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/5777">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the subarray with given sum'x' </p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3991">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the sub array with given sum zero File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3268">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the largest sub array with equal number of 0's and 1's</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 21</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3270">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the largest sub array with equal number of 0's and 1's (Approach - 2)</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">08 : 55</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3272">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-blue"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation for find the largest subarray with equal number of 0's and 1's</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">36 : 23</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3992">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon document-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the largest sub array with equal number of 0's and 1's File</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 2 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3274">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Product of array without using division operator</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 37</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3278">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-blue"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of product of all elements in the given array except arr[i] without using division operator</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">13 : 01</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3993">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon document-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Product of array without using division operator File</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 2 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3280">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Sort nearly sorted array using insertion sort</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 34</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3994">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon document-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Sort nearly sorted array using insertion sort File</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3281">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the duplicate in o(n) time and o(1) extra space</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 15</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3282">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of find the duplicate in o(n) time and o(1) extra space</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">01 : 23</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3996">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon document-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the duplicate in o(n) time and 0(1) extra space File</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 2 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3283">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the two repeating elements in a given array Approach-1</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 15</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3284">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the two repeating elements in a given array Approach-2</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">01 : 49</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3285">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the two repeating elements in a given array Approach-3</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 47</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3286">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-blue"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the two repeating elements in a given array Approach-4</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">11 : 14</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3287">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the two repeating elements in a given array Approach-5</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 31</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3288">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-blue"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation for finding the two repeating elements in the given array</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">09 : 38</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3997">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find two repeating elements File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3289">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Rotate the array of size n by d elements Approach-1</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 45</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3290">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Rotate the array of size n by d elements Approach-2</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 08</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3291">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Rotate the array of size n by d elements Approach-3</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 12</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3292">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Rotate the array of size n by d elements Approach-4</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 02</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3998">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon document-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Rotate an array of size n by d-elements File</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3999">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon document-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Rotate an array of size n by d -elements by juggling algorithm File</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 2 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/6237">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Sort an array in wave form</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 17</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3295">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of sort an array in wave form</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">01 : 28</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4000">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon document-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Sort an array in wave form File</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3297">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Next greater number with same set of digits Approach-1</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 25</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3298">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Next greater number with same set of digits Approach-2</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">12 : 25</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3299">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of next greater number with same set of digits</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 51</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4001">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon document-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Next greater number with same set of digits File</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 2 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3300">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Trapping Rain Water problem</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 42</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3331">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Trapping Rain Water problem Algorithm</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 37</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3332">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation Trapping Rain water</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 54</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4002">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon document-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Trapping water problem File</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3333">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Number of possible triangles Approcach-1</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 09</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3334">
                                    <div class="milestone-holder">
                <span class="milestone">
                    <span class="ticked"></span>
                    <span class="milestone-icon video-green"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Algorithm for number of possible triangles Approach-2</p>
                                            <p class="curriculam-info-view text-right orange-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="orange-eye"></span> 1 / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">16 : 33</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3335">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-blue"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Given An Array of positive numbers, find smallest number that cannot be formed with sum of numbers from an array</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">14 : 54</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3336">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Rearrange the array so that a[i] becomes a[a[i]]</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">13 : 53</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4003">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Rearrange the array so that a[i] becomes a[a[i]] File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3337">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Rotate square matrix by 90 degress</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 27</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3338">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of Rotate square matrix by 90 degrees</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">11 : 50</p>
                                    </div>
                                </a>
                            </div><div class="curriculam-title"><h4>Linked List</h4></div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3339">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Notations that we will be using in our code</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 56</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3340">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of reverse a linked list</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">12 : 50</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3341">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Finding a middle node in list</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 06</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3342">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation for find a middle node in a linked list</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 31</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4004">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find middle node in linked list (using single pointer ) File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4005">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find middle node in linked list (using fast pointer and slow pointer ) File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3343">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find Kth node from the end of linked list</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 09</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3344">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find Kth node from the end of linked list (Implementation in C)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">08 : 12</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3345">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find Kth node from the end of linked list (Implementation in C)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">08 : 12</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3346">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find kth node from the end of linked list (Hash Approach)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 44</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3347">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation for kth node from end</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 33</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4006">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find kth node from end File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3348">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Given a linked list, Check if the linked list has loop</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 45</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3349">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Given a Linked list, Check if the linked list has loop (Approach-1)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 22</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3350">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Given a Linked list, Check if the linked list has loop (Approach - 2)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 42</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3351">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Given a Linked list, Check if the linked list has loop (Approach - 3)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 46</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3352">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Floyd's Cycle-Finding Algorithm</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">12 : 30</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3353">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation for detect a loop in a linked list</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 23</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3354">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the starting node of cycle if cycle exists in a given linked list</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">12 : 28</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3355">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation for find the start node of the loop,if there is a cycle in a link</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 06</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3356">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Given a Linked list, Check if the linked list has loop (Implementation - C)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 56</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4007">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Given a Linked list, Check if the linked list has loop and find start node of the loop</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3357">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Applications of linked list</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">09 : 19</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3359">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Intersect point of two single linked lists</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 35</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3360">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Intersect point of two single linked lists (Approach - 2)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 30</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3361">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold"> Intersect point of two single linked lists (Approach - 3)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 34</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3362">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Intersect point of two single linked lists (Approach - 4)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 34</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3363">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Intersect point of two single linked lists (Approach - 5)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 35</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3364">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation for find intersection point of two linked list</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 34</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4008">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Intersect point of two single linked lists File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3365">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Alternating split of a given linked list</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 51</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3366">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of Alternating split of a given linked list</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 34</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4009">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Alternating split of a given linked list File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3368">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Introduction to Cloning the list</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 26</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3370">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Application for Cloning the list</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 06</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3372">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Cloning the list (Approach - 1)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 07</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3373">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Cloning the list (Approach - 2)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">09 : 44</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3374">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Cloning the list (Approach - 3)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">10 : 17</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3376">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Cloning the list (Approach - 4)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">12 : 14</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3381">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Cloning the list (Implementation -C)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">17 : 02</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3383">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Cloning the list (Implementation II - C)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">14 : 08</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3384">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation for clone a linked list with next and random pointer</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">12 : 02</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4010">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Cloning a linked list File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3387">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Check whether given linked list is palindrome or not (Approach - 3)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">08 : 04</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3385">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Check whether given linked list is palindrome or not</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">10 : 01</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3386">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Check whether given linked list is palindrome or not (Approach - 2)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 48</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3388">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Check whether given linked list is palindrome or not (Implementation - C)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">12 : 11</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3389">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Merge two sorted linked lists into one sorted linked list</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 38</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3390">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Merge two sorted linked lists into one sorted linked list (Approach - 2)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 12</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3391">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Merge two sorted linked list into one sorted linked list (Implementation-C)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">16 : 58</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4011">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Merge two sorted linked lists File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3392">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Merge K-sorted linked lists</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 33</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3393">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Merge k-sorted linked lists (Heap Approach)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">21 : 26</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3394">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Merge K-sorted linked lists (Approach-3)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 28</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3395">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Merge k-sorted linked lists ( Binary Search Tree Approach)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 42</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3396">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of merge k-sorted linked list</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 57</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4012">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Merge K-Sorted linked lists File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3397">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Merge sort on linked list</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 07</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3398">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Greatest value node in linked list on its right side</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 02</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3399">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation for finding Greatest value node in linked list on its right side</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 52</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4013">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Greatest value node in linked list on its right side File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3400">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Memory efficient Double Linked List</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 04</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3401">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Memory efficient Double Linked List insertion</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 15</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3402">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Memory efficient Double Linked List deletion</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">01 : 29</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3403">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of memory efficient double linked list</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 26</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4014">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Memory efficient double linked list File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3404">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Sort a linked list of 0's 1's and 2's</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 34</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3405">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Add 1 to number represented in linked list</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 24</p>
                                    </div>
                                </a>
                            </div><div class="curriculam-title"><h4>Hashing</h4></div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3406">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Check whether given array contains duplicates in k-distance or not approach-1</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 42</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3407">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Check whether given array contains duplicates in k-distance or not approach-2</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 24</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4909">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Check whether given array contains duplicates in k</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3408">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Check whether given two sets are disjoint or not approach-1</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">01 : 14</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3409">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Check whether given two sets are disjoint or not approach-2</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">01 : 07</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3410">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Check whether given two sets are disjoint or not approach-3</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">01 : 50</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3411">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Check whether given two sets are disjoint or not approach-4</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">01 : 22</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3412">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Check whether given two sets are disjoint or not approach-5</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">01 : 48</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4910">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Check whether given two sets are disjoint or not</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3413">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Group all the occurrences of elements order by their first occurrence (Approach - 1)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 48</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3414">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Group all the occurrences of elements order by their first occurrence (Approach - 2)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 51</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3415">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Group all the occurrences of elements order by their first occurrence (Approach - 3)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 15</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4911">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Group all the occurrences of elements order by their first occurrence</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3416">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Given an array A, Count the distinct elements in all windows of size K (Approach - 1)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 05</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3417">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Given an array A, Count the distinct elements in all windows of size K (Approach - 2)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 20</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3418">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Given an array A, Count the distinct elements in all windows of size K (Approach - 3)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 37</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4912">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Given an array a count the distinct elements in all windows of size K</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3419">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Given an array and a range[low, high], Find the elements that are in the range but not in the array (Approach - 1)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 33</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3420">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Given an array and a range[low, high], Find the elements that are in the range but not in the array (Approach - 2)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 01</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3421">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Given an array and a range[low, high], Find the elements that are in the range but not in the array (Approach - 3)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">01 : 23</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4913">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Given an array and a range low and high find the elements that are in range</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3422">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Given an array, print all subarrays in the array which has sum 0 (Approach - 1)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 51</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3423">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Given an array, print all subarrays in the array which has sum 0 (Approach - 2)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 06</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3424">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Given an array, print all subarrays in the array which has sum 0 (Approach - 3)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 10</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4914">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Given an array print all sub arrays in the array which has sum 0</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3425">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find four elements i,j,k and l in an array such that i+j=k+l (Approach - 1)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 25</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3426">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find four elements i,j,k and l in an array such that i+j=k+l (Approach - 2)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 02</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3427">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find four elements i,j,k and l in an array such that i+j=k+l (Approach - 3)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 05</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4915">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find four elements i,j,k,l in an array such that i+j=k+l</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="curriculam-title"><h4>Stacks</h4></div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3428">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implement a stack using queues</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 07</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3429">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Design a stack such that get minimum () should be 0(1)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 29</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3430">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Design a stack such that get minimum() should be constant time and space</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">12 : 24</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3431">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Reversal of a stack</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 31</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3432">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the closest greater element which is present on the right side of the element</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 38</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3433">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the closest greater element which is present on the right side of the element (Approach - 2)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">10 : 13</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3434">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of next greater element</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 02</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4916">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Next closest greater element File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3435">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implement stack with push ,pop, find middle element, delete middle element in 0(1)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">11 : 43</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3436">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Merge overlapping intervals</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 27</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3437">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Merge overlapping intervals (Approach - 2)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 10</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3438">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of merge over lapping intervals</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 07</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4917">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Merge overlapping intervals File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3439">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Check whether parenthesis balanced or not</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 14</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3440">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Stock span problem</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">08 : 21</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3442">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Stock span problem (Approach - 1)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">16 : 50</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3443">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Stock span problem (Implementation - C)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 58</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4918">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Stock Span Problem File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3444">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Minimum number of bracket reversals needed to make an expression balanced</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 56</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3445">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of minimum number of bracket reversals needed to make an expression balanced</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 52</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4919">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Minimum number of brackets reversals needed to make an expression balanced File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3446">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find if an expression has duplicate parenthesis or not</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 00</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3447">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of find if an expression has duplicate parenthesis or not</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 36</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4920">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find if an expression has duplicate parenthesis or not File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3448">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Celebrity problem approach-1 and 2</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 17</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3449">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Celebrity problem approach-3</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 27</p>
                                    </div>
                                </a>
                            </div><div class="curriculam-title"><h4>Queues</h4></div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3450">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the circular tour that visits all petrol pumps Approach-1</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">08 : 03</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3451">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the circular tour that visits all petrol pumps Approach-2</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 16</p>
                                    </div>
                                </a>
                            </div><div class="curriculam-title"><h4>Heaps</h4></div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3452">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find a maximum element in a min Heap</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 14</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3453">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of find a maximum element in a min heap</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">01 : 51</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4921">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find maximum element in min-heap File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3454">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Deleting an arbitary element from a min-heap</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 01</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3455">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">implementation to delete arbitrary element from min heap</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 36</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4922">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Deleting an arbitary element from a min-heap File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3456">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find k-largest elements from an array (Approach-1)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 04</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3457">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find k-largest elements from an array (Approach -2)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">01 : 32</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3459">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find k-largest elements from an array max heap (Approach-3)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 00</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3463">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find k-largest elements from an array max heap (Approach-4 )</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 38</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3469">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find k-largest elements from an array max heap (Approach-5)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">10 : 40</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3479">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find k-largest elements from an array max heap (Implementation - C)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 06</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3481">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find k-largest elements from an array max heap (Implementation II - C)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">01 : 57</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3482">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find k-largest elements from an array max heap (Implementation III - C)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 32</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3484">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation for finding K-largest element</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 19</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4923">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find k-largest elements from an array max heap</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3486">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find median in a stream of numbers (Approach - 1)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 58</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3487">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find median in a stream of numbers (Approach - 2)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">21 : 06</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3488">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find median in a stream of numbers (Approach - 3)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">14 : 38</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3489">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find median in a stream of numbers (Approach - 4)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">10 : 21</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3490">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of find median in a stream of numbers</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 29</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4924">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find Median in a Stream of Numbers File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3491">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Given k-sorted lists, Find the minimum range to which at last one number belongs from every list</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">17 : 29</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3492">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of given k-sorted lists,find range to which at least one number belongs from every list</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">12 : 39</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4925">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Given k-sorted lists,find range to which atleast one number belongs from every list File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3494">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Convert given max heap to min heap</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">01 : 39</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3495">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">implementation for converting minheap to maxheap</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 55</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4926">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Convert Minheap to Maxheap</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3496">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Print out all numbers in the form of a^3 + b^3</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 33</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3497">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of Printout all numbers in the form of a^3+b^3</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">09 : 51</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4927">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Printout all numbers in the form of a^3+b^3 File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3498">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Convert BST to Max Heap</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 47</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3500">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of BST to Max Heap</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">01 : 00</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4928">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Convert BST to Max Heap File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3501">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Choosing an effective data structure</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 30</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3502">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the kth largest element in a stream Approach-1</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 10</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3503">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the kth largest element in a stream Approach-2</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 07</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3504">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the kth largest element in a stream Approach-3</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">01 : 47</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3509">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation to find k-largest element in a stream of elements</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 25</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3515">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Tournment tree</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 32</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4929">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Tournament Tree node File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3517">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Print all elements in sorted order in row wise and column wise sorted matrix Approach 1</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 56</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3530">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Print all elements in sorted order in row wise and column wise sorted matrix Approach 2</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 15</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4931">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Print all elements in sorted order in row wise and column wise sorted matrix</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3531">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Sort a nearly sorted array Approach-1</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">01 : 20</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3534">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Sort a nearly sorted array Approach-2</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 00</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3537">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of sort a nearly sorted array</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 59</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4932">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Sort a nearly Sorted Array File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3540">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Given n-ropes with different length,connect with minimum cost</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 10</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3542">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of given n-ropes with different length,connect with minimum cost</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">01 : 43</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4933">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Given n-ropes with different length,connect with minimum cost File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3545">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Check whether given binary tree is max heap (or) not</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 02</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3548">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Given k-sorted arrays of size n each merge them</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">08 : 08</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3557">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of Given k-sorted array of size n each merge them</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">11 : 35</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4934">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Given k-sorted array of size n each merge them File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="curriculam-title"><h4>Trees</h4></div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3578">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Structure of a node in binary tree</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">01 : 44</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3583">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find size of the binary tree</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 43</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3588">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find size of the binary tree (Implementation - C)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">01 : 28</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3590">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation for finding the size of given binary tree</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">10 : 43</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4935">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Size_of_binary Tree</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3594">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Check wheather given two trees are identical or not</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 17</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3595">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Check wheather given two trees are identical or not (Implementation - C)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">01 : 48</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3596">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation for checking whether the given two trees are identical or not</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">08 : 02</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4936">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Check_identical_trees</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3600">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Construct a binary tree from post order and inorder</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 28</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3601">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Mirror Tree (Implementation - C)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 10</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3602">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of convert the given binary tree into its mirror tree</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 48</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4937">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">mirror_tree</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3603">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Level order Traversal</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 59</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3604">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Level order Traversal (Implementation - C)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 43</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3605">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of level order tree traversal</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">09 : 20</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4938">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Level Order Traversal</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3606">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find a lowest common ancestor of a given two nodes in a Binary Search Tree</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">10 : 24</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3607">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find a lowest common ancestor of a given two nodes in a Binary Search Tree (Implementation - C)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 16</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3608">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of finding lowest common ancestor in given binary search tree</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 35</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4939">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find_LCA_in_BST</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3609">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the lowest common ancestor of given two nodes in a binary tree (Approach - 1)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 31</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3610">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the lowest common ancestor of given two nodes in a binary tree (Approach - 2)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 17</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3611">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find a lowest common ancestor of a given two nodes in a binary tree (Implementation - C)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 04</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3612">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of finding the lowest common ancestor in given binary tree</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 23</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4940">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find_LCA_in_BT</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3613">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Convert a given binary tree into Doubly linked list (Approach-1)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">13 : 16</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3614">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Convert a given binary tree into Doubly linked list (Approach-2)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 09</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3615">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Convert a given binary tree into Doubly linked list (Approach-3)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 09</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3616">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of convert a given binary tree into doubly linket list</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 05</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4941">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">least common ancestor of two nodes in binary search tree</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3617">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the Diameter of a given binary tree</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 32</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3618">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the Diameter of a given binary tree (Implementation - C)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 09</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4942">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Diameter_of_Binary Tree</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3619">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Get the level of a given key in a binary tree</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 52</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3620">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Print nodes k-distance from root (Approach-1)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">10 : 23</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4943">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Print nodes_K dist</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3621">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Print nodes which are at k distance from a given key in a binary tree</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">09 : 11</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3630">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of print nodes which are at k distance from a given key in a binary Tree</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 09</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4944">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Print nodes which are at k-distance from a given key in a binary tree File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3636">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">vertical tree order traversal introduction</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 16</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3639">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Vertical tree order traversal (Approach-1)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 28</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3644">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">implementation of Print a Binary Tree in Vertical order set-1</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">12 : 48</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3651">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Vertical tree order traversal (Approach-2)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 22</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3654">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of Print a Binary Tree in Vertical order set-2 using hash table</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 20</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3658">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Vertical tree order traversal (Approach-3)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">08 : 53</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3699">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of vertical tree order traversal</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 31</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4945">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Vertical Tree order traversal File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3720">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Vertical sum of a given binary tree</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 31</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4962">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of vertical sum of a given binary tree</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 46</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4946">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Vertical sum of a given binary tree File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3721">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Check wheather the given binary tree is sum tree or not</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">11 : 11</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3722">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of check whether the given binary tree is sum tree or not</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 46</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4947">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Check whether the given tree is sum tree or not File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3723">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Print Top view of a Binary tree</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 54</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4948">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Print Top View of Binary Tree File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3724">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Print Bottom view of a Binary tree</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 05</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3725">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Print Left view of a Binary tree</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 40</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3726">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Print Left view of a Binary tree (Implementation - C)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 17</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3727">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Remove all paths of length</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 12</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4949">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Remove paths_Less than k</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3729">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Check whether a given binary tree is sub tree of another binary tree (Approach-1)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 58</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3730">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Check whether a given binary tree is sub tree of another binary tree (Approach-2)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">11 : 49</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3731">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of whether a given binary tree is subtree of another binary tree</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 20</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4950">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Whether a given binary tree is subtree of another binary tree File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3733">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Check wheather given two nodes are cousins in a binary tree</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 29</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3734">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of check whether given two nodes are cousins in a binary tree</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 20</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4951">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Check whether given two nodes are cousins in a binary tree File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3736">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Form a balanced binary search tree from given sorted array</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 25</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3738">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Form a balanced binary search tree from given sorted array (Implementation - C)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 37</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4952">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Form a balanced binary search tree from given sorted array File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3740">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Convert a given binary search tree into balanced binary tree</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 13</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3749">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of convert a given binary search tree into balanced binary tree</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">09 : 31</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4953">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">BST to Balanced BST</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3755">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Print out all root to leaf of a binary tree</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">11 : 12</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3774">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Level order traversal in spiral form</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 22</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3777">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of level order traversal in spiral form</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 09</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3780">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Construct a binary tree from post order and inorder</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 28</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3787">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of Inorder and pre order</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">17 : 06</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3819">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Print all nodes that are at distance k from a leaf node</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">09 : 56</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3820">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Evalution of expression of expression tree</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 52</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4954">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Evaluation of expression tree File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3821">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Print extreme node of each level in alternative order</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 44</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4955">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Print extreme node of each level in alternative order File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3822">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Diagonal traversal of a binary tree</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 36</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3823">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Convert a binary tree to a tree holds children sum property</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 59</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4956">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Convert a binary tree to a tree holds children sum property File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3824">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find multiplication of sums of data at same level in a tree</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 05</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4957">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find multiplication of sums of data at same level in a tree</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3825">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find maximum difference between node and it's ancestor in a binary tree</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">18 : 16</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4958">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find maximum difference between node and its ancestor</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3826">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Serialize and Deserialize a binary tree part-1</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">10 : 27</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3827">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Analysis of Serialize and deserialize a binary tree part-2</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">10 : 54</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3828">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of serialization</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">01 : 53</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3829">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of Deserialization</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">09 : 31</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3830">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Serialize and Deserialize an N-ary tree</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">09 : 40</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3831">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of serialize and deserialize N-ary tree</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 07</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3832">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of Serialization and Deserialization N-ary tree</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">12 : 47</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3833">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Construct a tree from ancestor matrix</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 18</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3834">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Construct a complete binary tree from it's linked list representation</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 06</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3835">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of construct a complete binary tree from its Linked list representation</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 42</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3836">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the next right node of a given key</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 01</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3837">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of find next right node of a given key</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">11 : 51</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3838">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Boundary traversal of a given tree</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 10</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3840">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of Boundary Traversal</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">23 : 08</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3841">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Convert a given tree to it's sum tree</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">09 : 56</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3842">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Check whether given tree is foldable (or) not</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 11</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4959">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Check whether given tree is foldable (or) not File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3843">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">If removing edge can divide a binary tree into two halfs</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 02</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4960">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">If removing edge can divide a binary tree into two halves</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3844">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Lock and unlock the resources that are arranged in k-ary tree</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">11 : 41</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3845">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Reverse alternate levels of perfect binary tree</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">13 : 38</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4961">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Reverse alternate levels of perfect binary tree</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3846">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Custom tree problem</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">11 : 46</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3847">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Threaded binary tree</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">14 : 26</p>
                                    </div>
                                </a>
                            </div><div class="curriculam-title"><h4>Strings</h4></div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3769">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find a maximum occurring character in a given string (Approach - 1)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 14</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3770">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find a maximum occurring character in a given string (Approach -2)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 51</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3771">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find a maximum occurring character in a given string (Approach - 3)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 30</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3772">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find a maximum occurring character in a given string (Approach - 4)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 42</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3773">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">implementation to find a character which appears maximum number of times on string</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 36</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4963">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find a maximum occurring character in a given string File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3775">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Remove duplicates from a given string (Approach-1)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 50</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3776">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Remove duplicates from a given string (Approach - 2)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 02</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3778">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Remove duplicates from a given string (Approach - 3)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 41</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3779">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Remove duplicates from a given string (Implementation - C)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 46</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4964">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Write an algorithm to remove all duplicates from a given string</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3781">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Check whether given two strings are rotations of each other or not (Approach-1)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 09</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3782">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Check whether given two strings are rotations of each other or not (Approach-2)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 53</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3783">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">implementation to check whether given two string are rotation of each other or not</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 17</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4965">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Program to check where given strings are rotations to each other with concatenation</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3784">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Reverse the words in a given sentence</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 19</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3785">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">implementation to reverse words in given string</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 18</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4966">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Reverse words in a given string</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3786">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Reverse a string</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 07</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3788">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Check whether given string is palindrome or not</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 36</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3789">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the first non-repeating character in a given string (Approach-1)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 25</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3790">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the first non-repeating character in a given string (Approach-2)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 02</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3791">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the first non-repeating character in a given string (Approach - 3)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 25</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3792">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of find first non-repeating character from a stream of characters</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">11 : 58</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4967">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the first non-repeating character in a given string File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3793">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Run length encoding</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 22</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3794">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">implementation of run length encoding</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">08 : 38</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4968">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Run length encoding File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3795">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Check whether given two strings are anagrams each other</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 16</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3796">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Check whether given two strings are anagrams each other (Implementation - C)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 19</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4969">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Check whether given two strings are anagrams each other File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3797">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find excel column name for given excel column number</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 31</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3798">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of find excel column name for given excel column number</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 55</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4970">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find excel column name for given excel column number</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3799">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the smallest window in a string containing all characters of another string</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 23</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3800">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the smallest window in a string continuing all characters of another string approach-2</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">16 : 34</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3801">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of find the smallest window in a string containing all characters of another string</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">12 : 53</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4971">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">C program to find smallest window containing all characters of a pattern</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3804">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find first non-repeating character from a stream of characters Approach-1</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 23</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3805">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find first non-repeating character from a stream of characters Approach-2</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 45</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4972">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">First non-repeating char from stream of chars File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3806">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">All combinations of string that can be used to dial a number</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 49</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3807">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Minimum number of palindromic subsequences to be removed to empty a balanced tree</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 57</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3808">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">implementation to minimum number of palindrome subsequence file</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">01 : 52</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3809">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">check if given sequences of moves for a robot is circular or not</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 53</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3810">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Check if given sequences of moves for a robot is circular or not</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 53</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4973">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Robot is circular or not</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3811">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of check if given sequence of moves for a robot is circular or not</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 47</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3812">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Maximum and minimum of an array using minimum number of comparison Approach-1</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 06</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3813">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Maximum and minimum of an array using minimum number of comparison Approach-2</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 08</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3814">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of maximum and minimum of an array using minimum number of comparisons</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 30</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4974">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">If n is odd then initialize min and max as first element</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3815">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Convert one string to another string using minimum number of given operation</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 30</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3816">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Print concatenation of zig-zag string in k-rows</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 40</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3817">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Remove adjacent duplicate characters in a given string</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">18 : 12</p>
                                    </div>
                                </a>
                            </div><div class="curriculam-title"><h4>Divide and Conquer</h4></div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3728">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Finding a majority element using Linear search</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 31</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3732">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Finding a majority element using Binary search</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">12 : 14</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3735">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">implementation of Majority element check</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 49</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4975">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Check whether given integer x is a majority element or not in a sorted array</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3737">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Nuts and bolts problem</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 05</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3739">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of Nuts and Blots problem</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 13</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4976">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Nuts and Bolts problem File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3741">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Write a custom c-function to implement pow() function</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 22</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3742">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">calculating power function</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 01</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3743">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Search an element in sorted rotated array (Approach-1)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 00</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3744">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Search an element in sorted rotated array (Approach-2)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 10</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4977">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Search an element in sorted rotated array File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3745">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">count inversions in an array approach-1</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 40</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3746">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">count inversions in an array approach-2</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">13 : 41</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3747">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">implementation of count-inversion in an array</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">11 : 12</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4978">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find inversion count of an array using merge sort</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3748">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Finding the missing number in arithmetic progression approach -1</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 25</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3750">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">finding the missing number in arithmetic progression approach -2</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 18</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3751">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Finding the missing number in arithmetic progression (Implementation-C)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 25</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4979">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find missing number in Arithmetic Progression File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3752">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Given an array containing 1's and 0's in which all 0's appear before all 1's then count the number of 1's in an array</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 31</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3753">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of given an array containing 1's and 0's in which all 0's appear before all 1's then count the number of 1's in an array</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 39</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4980">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find number of zeros in an array</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3754">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Given an array 2n integer in the following format a1,a2,a3,.... b1,b2,bn shuffle the array to a1b1 a2b2 a3b3... anbn approach-1</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 35</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3756">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Given an array 2n integer in the fallowing format a1,a2,a3,.... b1,b2,bn shuffle the array to a1b1 a2b2 a3b3... anbn approach-2</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 54</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3757">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of Given an array 2n integer in the following format a1,a2,a3,.... b1,b2,bn shuffle the array to a1b1 a2b2 a3b3</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 36</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3758">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Given a sorted array of non repeated integer a[1---n], check whether there is an index i for which a[i] =i</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 15</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3759">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">implementation of Given a sorted array of non repeated integer a[1---n], check whether there is an index i for which a[i] =i</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 47</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3760">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the maximum element index in an array which is first increasing and then decreasing</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 56</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3761">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of find maximum element index in an array which is first increasing and then decreasing</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 09</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4981">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Get maximum element in which all elements are distinct</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3762">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Search an element in row wise and column wise sorted 2d array</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 42</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3763">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of Search an element in row wise and column wise sorted 2d array</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 30</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4982">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Search an element in row wise and column wise 2d sorted array</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3764">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">External sorting</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 21</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3765">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find median of two sorted arrays</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">12 : 57</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3766">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">implementation of Median of 2 array</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">08 : 46</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3767">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">implementation of find peak element</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 43</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3768">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">implementation of Get first one</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 12</p>
                                    </div>
                                </a>
                            </div><div class="curriculam-title"><h4>Greedy Algorithms</h4></div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3848">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Connecting n ropes with minimum cost</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 56</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3849">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of connecting n ropes with minimum cost</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 05</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3850">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Interval scheduling</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">09 : 32</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4983">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Interval Scheduling File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3851">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Number of railway platforms</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 12</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3852">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of Minimum number of platforms</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">08 : 38</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3853">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Rearrange the string such that same characters are 'd' distance away</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 25</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4984">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Rearrange the string such that same characters are 'd' distance away</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="curriculam-title"><h4>Backtracking</h4></div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3854">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Introduction to backtracking</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 43</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3855">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Print all permutations of given string</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 39</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3856">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of print all permutations of given string</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 55</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4985">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Print all permutations of given string File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3858">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Print all the strings of n-bits</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">13 : 08</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3859">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">N-Queens problem (Approach -1)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">09 : 10</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3860">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">N-Queens problem (Approach -2)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">10 : 27</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4986">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">N-Queens problem File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3870">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Rat in a Maze (Approach - 1)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 11</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3861">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Rat in a Maze (Approach - 2)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 43</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4987">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Rat in a Maze File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3862">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">The Knight Tour problem (Approach -1)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">08 : 11</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3863">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">The Knight Tour problem (Approach -2)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 02</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4988">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">The Knight Tour problem File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3864">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find subset of elements that are selected from a given sum adds upto a given number k</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 49</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3865">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Solve Sudoku</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 34</p>
                                    </div>
                                </a>
                            </div><div class="curriculam-title"><h4>Dynamic Programming</h4></div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3460">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the maximum sum sub array (Approach - 1)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 28</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3461">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the maximum sum sub array (Approach - 2)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">08 : 48</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3462">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of max sum sub array</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 06</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/5393">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the maximum sum sub array file</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3464">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Maximum sum increasing subsequence</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 05</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3466">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of maximum sum increasing subsequence</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 19</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4989">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Maximum sum increasing sub sequence File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3465">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the longest subsequence in an array, such that elements in subsequence are consecutive (Approach - 1)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 49</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3467">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the longest subsequence in an array, such that elements in subsequence are consecutive (Approach - 2)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 53</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3468">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Given a Binary matrix, find the largest square sub matrix with all 1's (Approach - 1)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 31</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3470">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Given a Binary matrix, find the largest square sub matrix with all 1's (Approach - 2)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">11 : 32</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3471">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Example on Squares submatrix</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 16</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3472">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Introduction to the ugly number</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 51</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3473">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the kth ugly number (Approach - 1)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 53</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3474">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the kth ugly number (Approach - 2)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">13 : 41</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3475">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of Kth ugly number</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 57</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4990">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find kth ugly number File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3476">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Longest increasing subsequence</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">01 : 57</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3477">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Longest increasing sub sequence (Approach - 1)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 18</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3478">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Longest increasing sub sequence (Approach - 2)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">18 : 04</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3480">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of Length of longest increasing sub sequence</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 54</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4991">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">longest_increasing_sub sequence</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3483">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Longest decreasing subsequence</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 53</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3485">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of length of longest decreasing sub sequence</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 13</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4992">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">longest_decreasing_sub sequence</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3493">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Perfect hill sequence</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">13 : 50</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3499">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Edit distance (Approach - 1)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 39</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3505">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Edit distance (Approach - 2)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">13 : 48</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3506">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of Edit Distance</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 55</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4993">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Edit_distance</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3507">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Largest sum independent set in binary tree (Approach - 1)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 21</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3508">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Largest sum independent set in binary tree (Approach - 2)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">11 : 20</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3510">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of Largest sum Independent set</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 01</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3511">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the number of n-bit integers which do not have any two consequent zeros (Approach - 1)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">01 : 05</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3512">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the number of n-bit integers which do not have any two consequent zeros (Approach - 2)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 09</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3513">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of find the number of n-bit integers which don't have any two consequent zeros</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 08</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4994">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the number of n-bit integers which do not have any two consequent zeros</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3514">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Word breaking problem (Approach - 1)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 55</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3516">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Word breaking problem (Approach - 2)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 47</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3518">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Word breaking problem(Dynamic Programming) (Approach - 2)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">14 : 44</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3519">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Partition problem (Approach - 1)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">01 : 51</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3520">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Partition problem (Approach - 2)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 29</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3521">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of Partition problem</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 44</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4995">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Partition problem File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3522">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Longest palindromic sub sequence (Approach - 1)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 18</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3523">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Longest palindromic sub sequence (Approach - 2)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">01 : 08</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3524">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Longest palindromic sub sequence (Approach - 3)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">16 : 35</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3525">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of Longest palindromic subsequence</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 39</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4996">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Longest Palindromic Sub sequence File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3526">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Number of ways to reach the top of n-stairs (Approach - 1)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 32</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3527">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Number of ways to reach the top of n-stairs (Approach - 2)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 19</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3528">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of number of ways to reach the top of n-stairs</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">01 : 31</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4997">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Number of ways to reach the top of n-stairs File </p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3529">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Longest non-overlapping repeating sub string (Approach - 1)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 17</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3532">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Longest non-overlapping repeating sub string (Approach - 2)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">16 : 01</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3533">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Minimum cost identical string(Approach - 1)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 09</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3535">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Minimum cost identical string(Approach - 2)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">22 : 11</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3536">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of minimum cost identical string</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 17</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4998">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Minimum cost identical string File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3538">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Count the number of times a string occurred as a sub sequence of other string</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 35</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3539">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of Count the number of times a string occured as a subsequence of other string</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">20 : 50</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/4999">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Count the number of times a sting occurred as a sub sequence of other string</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3541">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Coin change</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 13</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3543">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Coin change recursive formula</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">13 : 32</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3544">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of coin change recursive formula</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 27</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/5000">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Coin Change Problem File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3546">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Number of ways to fill 2xn board in 2X1</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 36</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3547">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Minimum cost path</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">14 : 59</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3549">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of minimum cost path</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">08 : 51</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/5001">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Minimum cost path File </p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3550">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">k-palindrome approach-1</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 39</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3551">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">K-palindrome approach-2</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 06</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3552">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">implementation for equlibrium index in an array</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 55</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3553">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Longest common subsequence order O(n) space</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 37</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3558">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the sum of digits in all numbers from 1 to N for a given N Approach-1</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 30</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3559">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the sum of digits in all numbers from 1 to N for a given N approach-2</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">13 : 31</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3560">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the sum of digits in all numbers from 1 to N for a given N Approach-2 example</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 49</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3561">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the sum of digits in all numbers from 1 to N for a given N Approach-2 algorithm</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 25</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3564">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Even Length substring such that sum of first half is equal to second half</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">11 : 15</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3565">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Largest independent set in a binary tree</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">17 : 33</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/5003">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Largest Independent Set File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3566">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Cutting a rod</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">16 : 39</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/5004">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Cutting a rod</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3567">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Longest palindromic substring approach-1</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 40</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3568">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Longest palindromic substring approach-2</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">08 : 17</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3571">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Longest palindromic substring approach-3</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">13 : 38</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3572">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Count all palindromic substrings in a string using simple approach</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 24</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3573">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Count all palindromic substrings in a string using recursion function</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 55</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3574">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Count all palindromic substrings in a string using dynamic programming</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 18</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3575">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Count all palindromic substrings in a string with example</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">08 : 12</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3576">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Count all distinct palindromic substrings of a given string</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">01 : 33</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3577">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Maximum sum in rectangle</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">12 : 35</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3579">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Maximum dot product</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">15 : 04</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3580">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Largest independent set problem Approach-1</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 19</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3599">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Largest independent set problem Approach-2</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">10 : 21</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3581">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Largest independent set problem Approach-3</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">13 : 41</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3582">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Egg dropping problem Introduction</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">11 : 28</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3585">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Egg dropping puzzel continued</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">12 : 35</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3584">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Dynamic program for egg dropping</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">10 : 26</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3586">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Non-Decreasing number with n-digits</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">09 : 41</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3589">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Weighted job scheduling</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">19 : 23</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3587">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of weighted job scheduling</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 11</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/5005">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">weighted job scheduling</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3591">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Count the number of ways to reach a given score in a game</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">17 : 08</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/5006">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Count the number of ways to reach a given score in a game where a move can earn 2 or 4 or 6</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3592">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the maximum coins you can collect by bursting balloons wisely</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">34 : 31</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3593">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Collect maximum coins in grid using two traversals</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">08 : 16</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/5007">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Collect maximum coins in grid using two traversals</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="curriculam-title"><h4>Pattern Matching</h4></div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3866">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Given a text and a pattern, Find all occurrences of pattern in a given text (Naive Approach)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 58</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3868">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of given text and a pattern ,find all occurrences of pattern in a given text (Naive Approach)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 17</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/5008">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Given text and pattern, Find all occurrences of pattern in a given text (Naive Approach)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3869">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Given a text and a pattern, Find all occurrences of pattern in a given text (Finite Automata)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 31</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3871">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Given a text and a pattern, Find all occurrences of pattern in a given text (Finite Automata - Construction)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">10 : 19</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3872">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Given a text and a pattern, find all occurrences of pattern in a given text using Knuth Morris Pratt (KMP) algorithm - 1</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">11 : 48</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3873">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Given a text and a pattern, find all occurrences of pattern in a given text using Knuth Morris Pratt (KMP) algorithm - 2</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 14</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/5009">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Given a text and pattern, Find all occurrence of pattern in a given text using Knuth Morris Pratt (KMP)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3875">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Boyer-Moore string matching Algorithm</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">16 : 26</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3876">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of boyer-moore string matching algorithm</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">10 : 02</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/5010">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Boyer-moore string matching algorithm File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3877">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Rabin-Karp string matching Algorithm</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 51</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3878">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find all occurrences of a given word in a matrix</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 50</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/5011">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Rabin-Karp string matching Algorithm File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="curriculam-title"><h4>Advanced Data Structures</h4></div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3622">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Design LRU cache replacement algorithm (Approach - 1)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">09 : 16</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3623">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Design LRU cache replacement algorithm (Approach - 2)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 30</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3624">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Design LRU cache replacement algorithm (Approach - 3)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 19</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3625">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Introduction to AVL trees and balancing</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">18 : 18</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3626">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Constructing AVL trees and time complexity analysis</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">16 : 51</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3627">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Construction of AVL tree</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">22 : 33</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3628">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Minimum and maximum nodes in an AVL tree of height h</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">14 : 10</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3629">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Introduction to Red Black Trees</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 02</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3631">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">search,findmax,findmin in Red Black trees</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">01 : 38</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3632">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Insertion in Red Black trees</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 20</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3633">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Insertion in Red Black trees (Case - 1)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 42</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3634">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Insertion in Red Black trees (Case - 2)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 54</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3635">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Insertion in Red Black trees (Case - 3)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">09 : 50</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3637">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Insertion in Red Black trees (Case - 4)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">12 : 40</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3638">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Insertion in Red Black trees (Case - 5)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 24</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3640">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Insertion in Red Black trees (Case - 6)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">08 : 58</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3641">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Insertion Example in Red Black Trees</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">12 : 14</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3642">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Deletion in Red Black Trees</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 07</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3643">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Deletion in Red Black Trees (Case - 1)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">00 : 40</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3645">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Double blackness during deletion</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 54</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3646">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Deletion in Red Black Trees (Case - 2)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 27</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3647">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Deletion in Red Black Trees (Case - 3)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">13 : 59</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3648">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Deletion in Red Black Trees (Case - 4)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">11 : 25</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3649">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Deletion in Red Black Trees (Case - 5)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">10 : 52</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3650">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Deletion in Red Black Trees (Case - 6)</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">10 : 21</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3652">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Deletion Example in Red Black Trees</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">22 : 08</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3653">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Maximum height of a Red Black Tree</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 34</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3655">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Comparison between AVL Tree and Red Black Tree</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 02</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3656">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Introduction to B-Trees</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 37</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3657">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Structure of B-Tree</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">12 : 39</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3659">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Searching in B-Tree</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 39</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3660">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Insertion in B-Tree</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">11 : 41</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3661">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Deletion in B-Tree</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">14 : 07</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3662">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Deletion in B-Trees Example</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">11 : 59</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3663">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Introduction to B+ Trees</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">08 : 42</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3664">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Structure of leaf nodes in a B+Trees</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 41</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3665">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Searching in B+Trees</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 42</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3666">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Insertion in B+ Trees</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">10 : 25</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3667">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Deletion in B+Trees</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 21</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3668">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Introduction to Splay Trees</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 55</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3669">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Searching in Splay Trees</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">01 : 56</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3670">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Insertion in Splay Trees</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 18</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3671">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Deletion in splay trees</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 43</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3672">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Introduction to Binomial Heaps</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 51</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3673">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Properties of Binomial Trees</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 07</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3674">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Properties of Binomial Heaps</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 28</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3675">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Structure of Binomial Heaps</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 04</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3676">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find the minimum key in a Binomial Min Heap</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 23</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3677">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Union of two Binomial Min Heaps</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">13 : 44</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3678">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Example on union of two Binomial Min Heaps</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 26</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3679">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Insert a node into Binomial Min Heap</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">09 : 00</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3680">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Extract minimum from a Binomial Min Heap</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 15</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3681">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Example on Extracting minimum from a Binomial Min Heap</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 31</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3682">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Decreasing a key in Binomial Min Heap</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 17</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3683">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Deleting a node from Binomial Min Heap</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 56</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3684">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Introduction to Skip List</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 25</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3685">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Searching in Skip List</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 49</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3686">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Insertion in Skip List</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">13 : 26</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3687">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Deletion in Skip List</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 10</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3688">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Introduction to Trie</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 24</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3689">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Building a Trie</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 57</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3690">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation, insertion and searching in a Trie</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 44</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3691">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Deletion in Trie</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 54</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3692">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Compressed Trie</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 49</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3693">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Introduction to Ternary Search Tries</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 21</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3694">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Searching in Ternary Search Tries</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 26</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3695">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Insertion in Ternary Search Tries</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 08</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3696">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Deletion in Ternary Search Tries</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 50</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3697">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Comparison of Standard Tries with Ternary Search Tries</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">00 : 59</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3698">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Data Structure for Disjoint Sets</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 32</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3700">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Operations on Disjoint Sets</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 42</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3701">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Linked List representation of Disjoint Sets</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 10</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3702">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Time complexity for linked list representation of Disjoint Sets</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 21</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3703">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Amortized analysis of Disjoint Sets using linked list representation</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 37</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3704">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Disjoint set forest</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 47</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3705">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Union by rank</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 37</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3706">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Analysis union by rank</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">11 : 15</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3707">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Path compression</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 14</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3708">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Time complexity using the Heuristics</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 31</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3709">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Kruskal's algorithm using Disjoint sets</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">07 : 13</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3710">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Example on kruskal's using Disjoint sets</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">08 : 53</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3711">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Connected componands using Disjoints</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 47</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3712">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Example on connected components using Disjoint sets</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 55</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3714">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Introduction to Fibonacci Heap</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 29</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3715">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Structure of Fibonacci Heap</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">09 : 01</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3716">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Insert, find, min, Union</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 54</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3717">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Extract Min</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">10 : 58</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3718">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Decrease Key</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 15</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3719">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Fibonacci Heap Delete</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 35</p>
                                    </div>
                                </a>
                            </div><div class="curriculam-title"><h4>Graphs</h4></div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3879">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find if there is a path between two vertices vi and vj in a directed graph</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">01 : 54</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3880">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Given an undirected graph G(V,E), find whether G has cycle or not</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">01 : 42</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3881">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Example of an undirected graph G(V,E), find whether G has cycle or not</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 00</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3882">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Given an undirected graph G(V,E), find whether G has cycle or not using union-find</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 01</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3883">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Check whether given graph is biparite or not</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 28</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3884">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Check whether given graph is biparite or not</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 28</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3885">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Detect a cycle in a directed graph</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">01 : 45</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3886">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Print all jumping numbers smaller than (or) equal to given value</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 56</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3887">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Shortest path in a directed acyclic graph</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">11 : 54</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3888">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Longest path in directed acyclic graph</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">10 : 18</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3889">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Articulation points in a graph</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">18 : 36</p>
                                    </div>
                                </a>
                            </div><div class="curriculam-title"><h4>Bit Manipulation Algorithms</h4></div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3890">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Introduction to bit wise programming</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 16</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3891">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Check whether kth bit set (or) not</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 17</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/5037">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Check whether kth bit set or not File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3892">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Set kth bit of a number</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 19</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/5038">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">set Kth bit of a number File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3893">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Clear kth bit of number</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 28</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/5039">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Clear Kth bit of a number File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3894">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Toggle kth bit of number</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 11</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/5040">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Toggle Kth bit of number File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3895">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Count number of set bits in a number</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 15</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/5041">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Count number of set bits in a number File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3896">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Check whether the given number is power of 2</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 55</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/5042">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Check whether the given number is power of 2 File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3897">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find a next higher number of a given number which is a power of 2 approach -1</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 34</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3898">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find a next higher number of a given number which is a power of 2 approach -2</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 45</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/5043">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find a next higher number of a given number which is power of 2</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3899">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Check whether the given number is power of 4 approach -1</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 43</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3900">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Check whether the given number is power of 4 approach -2</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">01 : 42</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3901">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Check whether the given number is power of 4 approach -3</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">04 : 15</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/5044">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Check whether the given number is power of 4 File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3902">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Multiply a given number with 7 without using multiplication</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">01 : 42</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3903">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of bit manipulation problems</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">06 : 41</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/5045">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Multiply a given number with 7 without using multiplication File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="curriculam-title"><h4>Mathematical Algorithms</h4></div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3904">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Check whether given number is prime or not</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 10</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3905">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of check whether given number is prime or not</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">01 : 28</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/5046">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Check whether given number is prime or not File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3906">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Print all prime numbers up to n approach-1</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">01 : 43</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3907">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Print all prime numbers up to n approach-2</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">02 : 25</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3908">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Check whether given number is lucky (or) not</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">05 : 54</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/3909">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon video-grey"></span>
                </span>
                <div class="tail-up"></div><div class="tail-down"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of whether number is lucky or not</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2">03 : 01</p>
                                    </div>
                                </a>
                            </div><div class="timeline-row">
                                <a href="https://elearning.ravindrababuravula.com/materials/course/18/5047">
                                    <div class="milestone-holder">
                <span class="milestone">
                    
                    <span class="milestone-icon document-grey"></span>
                </span>
                <div class="tail-up"></div>
            </div>
                                    <div class="timeline-text text-justify">
                                        <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Check whether number is lucky or not File</p>
                                            <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
                                                <span class="green-eye"></span> - / 0
                                            </p>
                                        <p class="curriculam-info-duration text-right col-md-2"></p>
                                    </div>
                                </a>
                            </div></div>'''

# %%
soup = BeautifulSoup(html_str, 'html.parser') 
   
quotes=[]  # a list to store quotes 
   
table = soup.findAll(['p','div'], attrs = {"class":["curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold","curriculam-title"]})

# %%
for i in soup:
    import pdb;pdb.set_trace()
    print(i)
# Out:
# > <ipython-input-38-96eb325b0308>(3)<module>()
# -> print(i)
# (Pdb) i?
# *** SyntaxError: invalid syntax
# (Pdb) help(i)
# *** No help for '(i)'
# (Pdb) help?
# *** No help for '?'
# (Pdb) i
# <div class="changed-container-for-forum" id="curriculum_div"><div class="curriculam-container"><div class="curriculam-title"><h4>Instruction Note</h4></div><div class="timeline-row">
# <a href="https://elearning.ravindrababuravula.com/materials/course/7/6330">
# <div class="milestone-holder">
# <span class="milestone">
# <span class="milestone-icon code-grey"></span>
# </span>
# </div>
# <div class="timeline-text text-justify">
# <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Read Me First</p>
# <p class="curriculam-info-view text-right green-text col-md-2 col-sm-2 col-xs-3 visible-hidden">
# <span class="green-eye"></span> - / 0
#                                             </p>
# <p class="curriculam-info-duration text-right col-md-2"></p>
# </div>
# </a>
# ...

# %%
for i in table:
    if (i.get("class")[0] == "curriculam-title"):
        print("**********************************")
        print(i.text)
        print("**********************************")
    else:
        print(i.text)
# Out:
# **********************************
# Arrays
# **********************************
# Implementation of Linear search
# Implementation of Binary search
# Find a pair in an array whose sum is equal to given number
# Find a pair in an array whose sum is equal to given number (Hash Approach)
# Implementation to print all pairs in an array whose sum is X
# Find a pair whose sum is X (Hash approach)File
# Find a pair whose sum is x File
# Finding majority element approach-1 using linear search
# Moore voting algorithm
# Moore Voting Algorithm File
# implementation of finding the majority element in the given array
# Find the maximum difference between two elements in an array such that larger element appears after the smaller number (Approach-1)
# Find the max difference in an array so that the larger element has higher index than smaller element Approach-2
# Find the maximum difference between two elements in an array such that larger element appears after the smaller number (Approach-3)
# ...

# %% [markdown]
# # Problem solving using Data Structures and Algo

# %%
table
# Out:
# [<div class="curriculam-title"><h4>Arrays</h4></div>,
#  <div class="curriculam-title"><h4>Linked List</h4></div>,
#  <div class="curriculam-title"><h4>Hashing</h4></div>,
#  <div class="curriculam-title"><h4>Stacks</h4></div>,
#  <div class="curriculam-title"><h4>Queues</h4></div>,
#  <div class="curriculam-title"><h4>Heaps</h4></div>,
#  <div class="curriculam-title"><h4>Trees</h4></div>,
#  <div class="curriculam-title"><h4>Strings</h4></div>,
#  <div class="curriculam-title"><h4>Divide and Conquer</h4></div>,
#  <div class="curriculam-title"><h4>Greedy Algorithms</h4></div>,
#  <div class="curriculam-title"><h4>Backtracking</h4></div>,
#  <div class="curriculam-title"><h4>Dynamic Programming</h4></div>,
#  <div class="curriculam-title"><h4>Pattern Matching</h4></div>,
#  <div class="curriculam-title"><h4>Advanced Data Structures</h4></div>,
#  <div class="curriculam-title"><h4>Graphs</h4></div>,
#  <div class="curriculam-title"><h4>Bit Manipulation Algorithms</h4></div>,
# ...

# %%
table
# Out:
# [<div class="curriculam-title"><h4>Arrays</h4></div>,
#  <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of Linear search</p>,
#  <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation of Binary search</p>,
#  <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find a pair in an array whose sum is equal to given number</p>,
#  <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find a pair in an array whose sum is equal to given number (Hash Approach)</p>,
#  <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Implementation to print all pairs in an array whose sum is X</p>,
#  <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find a pair whose sum is X (Hash approach)File</p>,
#  <p class="curriculam-info-text col-md-8 col-sm-10 col-xs-9 info-bold">Find a pair whose sum is x File</p>,
# ...
